# %% [markdown]
# <a href="https://colab.research.google.com/github/phoebejeske/deep-learning/blob/main/assessment8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Anomaly detection with autoencoders
#
# In this notebook we you have to create a fully-connected neural network based autoencoder in order to detect credit card frauds. In the dataset there are 492 labeled frauds and 284807 normal transactions. First, let's download the dataset and unpack it (original source of the dataset: https://www.kaggle.com/mlg-ulb/creditcardfraud - before downloading the data please read and accept the licence of the original datasource):

# %%
# !wget https://www.deeplearningoktatas.hu/downloads/Anomaly/creditcardfraud.zip
# Out:
# --2024-05-09 17:18:47--  https://www.deeplearningoktatas.hu/downloads/Anomaly/creditcardfraud.zip
# Resolving www.deeplearningoktatas.hu (www.deeplearningoktatas.hu)... 91.227.138.51
# Connecting to www.deeplearningoktatas.hu (www.deeplearningoktatas.hu)|91.227.138.51|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 69155632 (66M) [application/zip]
# Saving to: ‘creditcardfraud.zip’
#
# creditcardfraud.zip 100%[===================>]  65.95M  18.4MB/s    in 4.7s
#
# 2024-05-09 17:18:53 (14.0 MB/s) - ‘creditcardfraud.zip’ saved [69155632/69155632]

# %%
# %%capture
# !unzip creditcardfraud.zip

# %% [markdown]
# ## Imports
# Import the necessary modules:

# %%
import pandas as pd #
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Dropout, Activation, Input
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.optimizers import SGD
from tensorflow.keras import regularizers
from sklearn import preprocessing
from sklearn.metrics import mean_squared_error
np.random.seed(123)

# %% [markdown]
# ## Exercise 1: Reading and preparing the data
# Read the creditcard.csv into a Pandas Dataframe with the [read_csv](https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html) function.

# %%
df = pd.read_csv('/content/creditcard.csv')

# %% [markdown]
# As the next step, select all the columns of the dataframe for the input X, but the "Class" column. And select the "Class" column for output Y. Make sure that both X and Y are two dimensional Numpy arrays.
#
# Hint:
# * you can use df.loc to select rows and columns from a dataframe
# * you can get the Numpy array of a Pandas object with .values, eg. df['myfeature'].values

# %%
X = df.loc[:, df.columns != 'Class']
Y = df['Class'].values

# %%
print("Shape of X:",X.shape)
print("Shape of Y:",Y.shape)
# Out:
# Shape of X: (284807, 30)
# Shape of Y: (284807,)

# %% [markdown]
# Let's standardize the data:

# %%
scaler = preprocessing.StandardScaler().fit(X)
X = scaler.transform(X)

# %% [markdown]
# ## Exercise 2: defining the autoencoder
# Let's define a model according to the following instructions:
# * the model's inputs and outputs should be the same as the number of X's features (columns)
# * the model should have 5 hidden layers, with 16-10-6-10-16 neurons in the hidden layers, respectively
# * all layers but the output should have tanh activation
# * the output layer should have linear activation

# %%
model = Sequential()
input = Input(shape=(X.shape[1],))
model.add(Dense(units=16, activation="tanh"))
model.add(Dense(units=10, activation="tanh"))
model.add(Dense(units=6, activation="tanh"))
model.add(Dense(units=10, activation="tanh"))
model.add(Dense(units=16, activation="tanh"))
model.add(Dense(units=30, activation="linear"))

# %% [markdown]
# ## Exercise 3: define early stopping compile the model, and train it
# Please pay attention to the following details:
# * use EarlyStopping with patience 10 and this time monitor the training loss
# * do not define validation data
# * use mean squarred error loss function
# * both the input and output of the model should be X this time. (as we are "auto encoding" the input to the output)

# %%
patience = 10
es = EarlyStopping(monitor='loss',
                   patience=patience,
                   verbose=1,
                   restore_best_weights=True)
model.compile(loss='mean_squared_error',
              optimizer='adam',
              metrics=['accuracy'])

# %%
history= model.fit(X, X, epochs=100,
          callbacks=[es],
          batch_size=32, shuffle=True
          )
# Out:
# Epoch 1/100
# 8901/8901 [==============================] - 24s 2ms/step - loss: 0.7555 - accuracy: 0.2272
# Epoch 2/100
# 8901/8901 [==============================] - 24s 3ms/step - loss: 0.6387 - accuracy: 0.3580
# Epoch 3/100
# 8901/8901 [==============================] - 21s 2ms/step - loss: 0.5904 - accuracy: 0.3823
# Epoch 4/100
# 8901/8901 [==============================] - 22s 2ms/step - loss: 0.5652 - accuracy: 0.3908
# Epoch 5/100
# 8901/8901 [==============================] - 21s 2ms/step - loss: 0.5520 - accuracy: 0.3946
# Epoch 6/100
# 8901/8901 [==============================] - 20s 2ms/step - loss: 0.5385 - accuracy: 0.4025
# Epoch 7/100
# 8901/8901 [==============================] - 23s 3ms/step - loss: 0.5232 - accuracy: 0.4089
# Epoch 8/100
# 8901/8901 [==============================] - 21s 2ms/step - loss: 0.5131 - accuracy: 0.4106
# Epoch 9/100
# 8901/8901 [==============================] - 23s 3ms/step - loss: 0.5067 - accuracy: 0.4110
# Epoch 10/100
# 8901/8901 [==============================] - 21s 2ms/step - loss: 0.5009 - accuracy: 0.4153
# Epoch 11/100
# 8901/8901 [==============================] - 25s 3ms/step - loss: 0.4964 - accuracy: 0.4166
# Epoch 12/100
# 8901/8901 [==============================] - 22s 2ms/step - loss: 0.4936 - accuracy: 0.4172
# Epoch 13/100
# 8901/8901 [==============================] - 25s 3ms/step - loss: 0.4910 - accuracy: 0.4194
# Epoch 14/100
# 8901/8901 [==============================] - 21s 2ms/step - loss: 0.4885 - accuracy: 0.4190
# Epoch 15/100
# 8901/8901 [==============================] - 23s 3ms/step - loss: 0.4862 - accuracy: 0.4195
# Epoch 16/100
# 8901/8901 [==============================] - 20s 2ms/step - loss: 0.4838 - accuracy: 0.4196
# Epoch 17/100
# 8901/8901 [==============================] - 22s 2ms/step - loss: 0.4821 - accuracy: 0.4196
# Epoch 18/100
# 8901/8901 [==============================] - 20s 2ms/step - loss: 0.4804 - accuracy: 0.4190
# Epoch 19/100
# 8901/8901 [==============================] - 20s 2ms/step - loss: 0.4786 - accuracy: 0.4202
# Epoch 20/100
# 8901/8901 [==============================] - 23s 3ms/step - loss: 0.4773 - accuracy: 0.4192
# Epoch 21/100
# 8901/8901 [==============================] - 21s 2ms/step - loss: 0.4755 - accuracy: 0.4192
# Epoch 22/100
# 8901/8901 [==============================] - 22s 2ms/step - loss: 0.4741 - accuracy: 0.4199
# Epoch 23/100
# 8901/8901 [==============================] - 20s 2ms/step - loss: 0.4731 - accuracy: 0.4193
# Epoch 24/100
# 8901/8901 [==============================] - 24s 3ms/step - loss: 0.4720 - accuracy: 0.4181
# Epoch 25/100
# 8901/8901 [==============================] - 20s 2ms/step - loss: 0.4706 - accuracy: 0.4191
# Epoch 26/100
# 8901/8901 [==============================] - 20s 2ms/step - loss: 0.4698 - accuracy: 0.4179
# Epoch 27/100
# 8901/8901 [==============================] - 22s 3ms/step - loss: 0.4722 - accuracy: 0.4158
# Epoch 28/100
# 8901/8901 [==============================] - 20s 2ms/step - loss: 0.4703 - accuracy: 0.4159
# Epoch 29/100
# 8901/8901 [==============================] - 23s 3ms/step - loss: 0.4685 - accuracy: 0.4164
# Epoch 30/100
# 8901/8901 [==============================] - 20s 2ms/step - loss: 0.4679 - accuracy: 0.4160
# Epoch 31/100
# 8901/8901 [==============================] - 20s 2ms/step - loss: 0.4673 - accuracy: 0.4157
# Epoch 32/100
# 8901/8901 [==============================] - 22s 2ms/step - loss: 0.4667 - accuracy: 0.4155
# Epoch 33/100
# 8901/8901 [==============================] - 20s 2ms/step - loss: 0.4658 - accuracy: 0.4157
# Epoch 34/100
# 8901/8901 [==============================] - 23s 3ms/step - loss: 0.4659 - accuracy: 0.4152
# Epoch 35/100
# 8901/8901 [==============================] - 21s 2ms/step - loss: 0.4645 - accuracy: 0.4149
# Epoch 36/100
# 8901/8901 [==============================] - 25s 3ms/step - loss: 0.4643 - accuracy: 0.4157
# Epoch 37/100
# 8901/8901 [==============================] - 21s 2ms/step - loss: 0.4642 - accuracy: 0.4148
# Epoch 38/100
# 8901/8901 [==============================] - 23s 3ms/step - loss: 0.4640 - accuracy: 0.4155
# Epoch 39/100
# 8901/8901 [==============================] - 21s 2ms/step - loss: 0.4636 - accuracy: 0.4145
# Epoch 40/100
# 8901/8901 [==============================] - 23s 3ms/step - loss: 0.4634 - accuracy: 0.4142
# Epoch 41/100
# 8901/8901 [==============================] - 22s 2ms/step - loss: 0.4647 - accuracy: 0.4151
# Epoch 42/100
# 8901/8901 [==============================] - 22s 3ms/step - loss: 0.4641 - accuracy: 0.4154
# Epoch 43/100
# 8901/8901 [==============================] - 22s 3ms/step - loss: 0.4631 - accuracy: 0.4155
# Epoch 44/100
# 8901/8901 [==============================] - 24s 3ms/step - loss: 0.4623 - accuracy: 0.4161
# Epoch 45/100
# 8901/8901 [==============================] - 22s 2ms/step - loss: 0.4619 - accuracy: 0.4169
# Epoch 46/100
# 8901/8901 [==============================] - 27s 3ms/step - loss: 0.4609 - accuracy: 0.4173
# Epoch 47/100
# 8901/8901 [==============================] - 21s 2ms/step - loss: 0.4609 - accuracy: 0.4169
# Epoch 48/100
# 8901/8901 [==============================] - 27s 3ms/step - loss: 0.4608 - accuracy: 0.4167
# Epoch 49/100
# 8901/8901 [==============================] - 21s 2ms/step - loss: 0.4592 - accuracy: 0.4166
# Epoch 50/100
# 8901/8901 [==============================] - 23s 3ms/step - loss: 0.4585 - accuracy: 0.4159
# Epoch 51/100
# 8901/8901 [==============================] - 21s 2ms/step - loss: 0.4587 - accuracy: 0.4142
# Epoch 52/100
# 8901/8901 [==============================] - 23s 3ms/step - loss: 0.4582 - accuracy: 0.4140
# Epoch 53/100
# 8901/8901 [==============================] - 21s 2ms/step - loss: 0.4579 - accuracy: 0.4142
# Epoch 54/100
# 8901/8901 [==============================] - 24s 3ms/step - loss: 0.4573 - accuracy: 0.4143
# Epoch 55/100
# 8901/8901 [==============================] - 21s 2ms/step - loss: 0.4582 - accuracy: 0.4125
# Epoch 56/100
# 8901/8901 [==============================] - 24s 3ms/step - loss: 0.4580 - accuracy: 0.4137
# Epoch 57/100
# 8901/8901 [==============================] - 21s 2ms/step - loss: 0.4568 - accuracy: 0.4130
# Epoch 58/100
# 8901/8901 [==============================] - 22s 3ms/step - loss: 0.4572 - accuracy: 0.4142
# Epoch 59/100
# 8901/8901 [==============================] - 24s 3ms/step - loss: 0.4568 - accuracy: 0.4131
# Epoch 60/100
# 8901/8901 [==============================] - 22s 2ms/step - loss: 0.4573 - accuracy: 0.4130
# Epoch 61/100
# 8901/8901 [==============================] - 21s 2ms/step - loss: 0.4566 - accuracy: 0.4139
# Epoch 62/100
# 8901/8901 [==============================] - 21s 2ms/step - loss: 0.4569 - accuracy: 0.4136
# Epoch 63/100
# 8901/8901 [==============================] - 23s 3ms/step - loss: 0.4567 - accuracy: 0.4128
# Epoch 64/100
# 8901/8901 [==============================] - 21s 2ms/step - loss: 0.4577 - accuracy: 0.4124
# Epoch 65/100
# 8901/8901 [==============================] - 22s 2ms/step - loss: 0.4570 - accuracy: 0.4124
# Epoch 66/100
# 8901/8901 [==============================] - 22s 2ms/step - loss: 0.4578 - accuracy: 0.4122
# Epoch 67/100
# 8901/8901 [==============================] - 21s 2ms/step - loss: 0.4573 - accuracy: 0.4111
# Epoch 68/100
# 8901/8901 [==============================] - 23s 3ms/step - loss: 0.4570 - accuracy: 0.4119
# Epoch 69/100
# 8901/8901 [==============================] - 20s 2ms/step - loss: 0.4579 - accuracy: 0.4123
# Epoch 70/100
# 8901/8901 [==============================] - 23s 3ms/step - loss: 0.4568 - accuracy: 0.4120
# Epoch 71/100
# 8901/8901 [==============================] - 21s 2ms/step - loss: 0.4558 - accuracy: 0.4124
# Epoch 72/100
# 8901/8901 [==============================] - 26s 3ms/step - loss: 0.4547 - accuracy: 0.4130
# Epoch 73/100
# 8901/8901 [==============================] - 22s 2ms/step - loss: 0.4560 - accuracy: 0.4129
# Epoch 74/100
# 8901/8901 [==============================] - 24s 3ms/step - loss: 0.4557 - accuracy: 0.4129
# Epoch 75/100
# 8901/8901 [==============================] - 21s 2ms/step - loss: 0.4546 - accuracy: 0.4134
# Epoch 76/100
# 8901/8901 [==============================] - 23s 3ms/step - loss: 0.4551 - accuracy: 0.4128
# Epoch 77/100
# 8901/8901 [==============================] - 21s 2ms/step - loss: 0.4549 - accuracy: 0.4134
# Epoch 78/100
# 8901/8901 [==============================] - 23s 3ms/step - loss: 0.4551 - accuracy: 0.4130
# Epoch 79/100
# 8901/8901 [==============================] - 21s 2ms/step - loss: 0.4545 - accuracy: 0.4135
# Epoch 80/100
# 8901/8901 [==============================] - 21s 2ms/step - loss: 0.4549 - accuracy: 0.4126
# Epoch 81/100
# 8901/8901 [==============================] - 23s 3ms/step - loss: 0.4542 - accuracy: 0.4134
# Epoch 82/100
# 8901/8901 [==============================] - 20s 2ms/step - loss: 0.4550 - accuracy: 0.4130
# Epoch 83/100
# 8901/8901 [==============================] - 23s 3ms/step - loss: 0.4554 - accuracy: 0.4128
# Epoch 84/100
# 8901/8901 [==============================] - 22s 3ms/step - loss: 0.4552 - accuracy: 0.4138
# Epoch 85/100
# 8901/8901 [==============================] - 22s 2ms/step - loss: 0.4552 - accuracy: 0.4155
# Epoch 86/100
# 8901/8901 [==============================] - 21s 2ms/step - loss: 0.4580 - accuracy: 0.4136
# Epoch 87/100
# 8901/8901 [==============================] - 23s 3ms/step - loss: 0.4558 - accuracy: 0.4145
# Epoch 88/100
# 8901/8901 [==============================] - 21s 2ms/step - loss: 0.4542 - accuracy: 0.4149
# Epoch 89/100
# 8901/8901 [==============================] - 23s 3ms/step - loss: 0.4536 - accuracy: 0.4157
# Epoch 90/100
# 8901/8901 [==============================] - 20s 2ms/step - loss: 0.4533 - accuracy: 0.4160
# Epoch 91/100
# 8901/8901 [==============================] - 23s 3ms/step - loss: 0.4544 - accuracy: 0.4167
# Epoch 92/100
# 8901/8901 [==============================] - 22s 3ms/step - loss: 0.4544 - accuracy: 0.4164
# Epoch 93/100
# 8901/8901 [==============================] - 22s 3ms/step - loss: 0.4534 - accuracy: 0.4174
# Epoch 94/100
# 8901/8901 [==============================] - 22s 2ms/step - loss: 0.4536 - accuracy: 0.4178
# Epoch 95/100
# 8901/8901 [==============================] - 22s 2ms/step - loss: 0.4543 - accuracy: 0.4180
# Epoch 96/100
# 8901/8901 [==============================] - 25s 3ms/step - loss: 0.4537 - accuracy: 0.4190
# Epoch 97/100
# 8901/8901 [==============================] - 21s 2ms/step - loss: 0.4545 - accuracy: 0.4180
# Epoch 98/100
# 8901/8901 [==============================] - 22s 3ms/step - loss: 0.4547 - accuracy: 0.4188
# Epoch 99/100
# 8901/8901 [==============================] - 21s 2ms/step - loss: 0.4538 - accuracy: 0.4206
# Epoch 100/100
# 8892/8901 [============================>.] - ETA: 0s - loss: 0.4544 - accuracy: 0.4199Restoring model weights from the end of the best epoch: 90.
# 8901/8901 [==============================] - 23s 3ms/step - loss: 0.4543 - accuracy: 0.4199
# Epoch 100: early stopping

# %% [markdown]
# ## Results analysis
# After training is done, we make predictions for the complete dataset and inspect the reconstruction loss. Our assumption is that, higher reconstruction loss are more likely to belong to anomalies than lower reconstruciton loss.

# %%
preds = model.predict(X)
errs  = np.square(preds-X)
errs  = np.mean(errs,axis=1)
# Out:
# 8901/8901 [==============================] - 15s 2ms/step

# %%
plt.figure(figsize=(16,10))
rng = np.arange(len(errs))
colors = ['g','r'] # green: normal, red: anomaly
for i in [0,1]:
    plt.scatter(rng[(Y==i).reshape(-1)], errs[(Y==i).reshape(-1)], color=colors[i])

# %%
Y_cut    = Y[errs<10]
errs_cut = errs[errs<10]

# %%
plt.figure(figsize=(16,10))
rng = np.arange(len(errs_cut))
colors = ['g','r']
for i in [0,1]:
    plt.scatter(rng[(Y_cut==i).reshape(-1)], errs_cut[(Y_cut==i).reshape(-1)], color=colors[i])

# %% [markdown]
# ## Exercise 4: finding the right treshold
# Find a treshold that identifies at least 130 anomalies correctly with as small number of missclassifications of non-anomalies as possible.

# %%
treshold = 4.82
errs_filtered               = errs[errs>treshold]
Y_filtered                  = Y[errs>treshold]
errs_filtered_non_anomalies = errs[errs<=treshold]
Y_filtered_non_anomalies    = Y[errs<=treshold]

print("Anomalies in the dataset") # Y_filtered==1
print("   predicted as anomaly:", len(errs_filtered[Y_filtered==1]))
print("   predicted as non-anomaly: ", len(errs_filtered_non_anomalies[Y_filtered_non_anomalies==1]) )
print("Non-anomalies in the dataset") # Y_filtered ==0
print("   predicted as anomaly:", len(errs_filtered[Y_filtered==0]))
print("   predicted as non-anomaly:", len(errs_filtered_non_anomalies[Y_filtered_non_anomalies==0]) )
# Out:
# Anomalies in the dataset
#    predicted as anomaly: 130
#    predicted as non-anomaly:  362
# Non-anomalies in the dataset
#    predicted as anomaly: 1815
#    predicted as non-anomaly: 282500

# %% [markdown]
# We can also inspect the confusion matrix:

# %%
from sklearn.metrics import confusion_matrix
conf=confusion_matrix(Y, errs>treshold)
import seaborn as sns
sns.heatmap(conf, annot=True, vmax=8000, fmt="d")
# Out:
# <Axes: >
